# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt

pd.options.display.max_columns = None

# %%
import plotly 
plotly.tools.set_credentials_file(username='max-farver', api_key='HbhTsxRXj15jBGOb2WXE')

# %%
df = pd.read_hdf('champ_clean_not_scaled.h5')

# %%
df = df.drop(['team', 'game_id'], axis=1)
df.head()
# Out:
#    game_duration       score     goals   assists     saves     shots  \
# 0          458.0  554.000000  2.333333  2.000000  0.333333  4.000000
# 1          458.0  330.333333  1.000000  0.666667  1.333333  1.333333
# 2          393.0  293.000000  0.333333  0.333333  2.000000  1.333333
# 3          393.0  510.333333  2.000000  1.333333  0.333333  4.666667
# 4          304.0  198.333333  0.000000  0.000000  1.333333  1.000000
#
#           bpm  amount_collected  amount_collected_big_pads  \
# 0  407.000000       2594.333333                1275.666667
# 1  330.333333       2239.333333                 852.000000
# 2  414.333333       2271.333333                1150.000000
# 3  296.666667       1635.666667                1037.666667
# 4  329.333333       1603.000000                 872.333333
#
#    amount_collected_small_pads  count_collected_big_pads  \
# 0                  1318.666667                 29.000000
# 1                  1387.333333                 21.666667
# 2                  1121.333333                 16.666667
# 3                   598.000000                 14.666667
# 4                   730.666667                 13.333333
#
#    count_collected_small_pads  amount_stolen  amount_stolen_big_pads  \
# 0                   50.000000     554.000000              183.000000
# 1                   56.000000     786.333333              225.666667
# 2                   49.666667     456.333333              134.666667
# 3                   33.666667     324.000000              126.333333
# 4                   43.666667     321.333333              128.333333
#
#    amount_stolen_small_pads  count_stolen_big_pads  count_stolen_small_pads  \
# 0                371.000000               4.000000                12.000000
# 1                560.666667               6.333333                20.666667
# 2                321.666667               2.000000                13.666667
# 3                197.666667               3.000000                10.000000
# 4                193.000000               2.333333                10.333333
#
#    0_boost_time    avg_speed  total_distance  time_slow_speed  \
# 0     43.680000  1569.000000   562555.666667       172.870000
# 1     41.920000  1446.666667   518660.000000       211.533333
# 2     52.833333  1508.666667   468653.666667       163.346667
# 3     34.743333  1351.000000   414395.666667       205.533333
# 4      7.583333  1452.333333   393542.333333       144.316667
#
#    time_boost_speed  time_supersonic_speed  time_on_ground  time_low_in_air  \
# 0        171.836667              55.246667      226.233333       156.923333
# 1        154.580000              33.803333      245.156667       143.940000
# 2        126.136667              46.946667      204.176667       123.816667
# 3        108.816667              22.180000      218.540000       107.466667
# 4        109.583333              28.770000      163.063333       106.376667
#
#    time_high_in_air  avg_distance_to_ball  \
# 0         16.796667           3227.000000
# 1         10.820000           2958.000000
# 2          8.433333           2443.666667
# 3         10.526667           2922.666667
# 4         13.226667           2704.666667
#
#    avg_distance_to_ball_has_possession  avg_distance_to_ball_no_possession  \
# 0                          3160.333333                         3349.666667
# 1                          3034.666667                         2880.333333
# 2                          2244.000000                         2568.666667
# 3                          3077.333333                         2666.000000
# 4                          2531.333333                         2888.666667
#
#    time_behind_ball  time_in_front_of_ball  time_defensive_half  \
# 0        299.103333                 100.85           249.120000
# 1        276.066667                 123.85           292.890000
# 2        221.570000                 114.86           209.313333
# 3        246.806667                  89.73           228.040000
# 4        192.236667                  90.43           194.620000
#
#    time_offensive_half  time_defensive_third  time_neutral_third  \
# 0           150.833333            176.430000          128.640000
# 1           107.023333            221.820000          128.290000
# 2           127.120000            158.243333           99.946667
# 3           108.493333            173.393333           98.256667
# 4            88.046667            145.150000           89.620000
#
#    time_offensive_third  demos_inflicted  demos_taken  game_duration_diff  \
# 0             94.883333         0.333333     0.333333                 0.0
# 1             49.810000         0.333333     0.333333                 0.0
# 2             78.240000         0.333333     0.333333                 0.0
# 3             64.890000         0.333333     0.333333                 0.0
# 4             47.893333         0.000000     1.000000                 0.0
#
#    score_diff  goals_diff  assists_diff  saves_diff  shots_diff    bpm_diff  \
# 0  223.666667    1.333333      1.333333   -1.000000    2.666667   76.666667
# 1 -223.666667   -1.333333     -1.333333    1.000000   -2.666667  -76.666667
# 2 -217.333333   -1.666667     -1.000000    1.666667   -3.333333  117.666667
# 3  217.333333    1.666667      1.000000   -1.666667    3.333333 -117.666667
# 4 -123.666667   -1.000000     -0.666667    1.000000   -1.333333   12.000000
#
#    amount_collected_diff  amount_collected_big_pads_diff  \
# 0             355.000000                      423.666667
# 1            -355.000000                     -423.666667
# 2             635.666667                      112.333333
# 3            -635.666667                     -112.333333
# 4              81.666667                        9.000000
#
#    amount_collected_small_pads_diff  count_collected_big_pads_diff  \
# 0                        -68.666667                       7.333333
# 1                         68.666667                      -7.333333
# 2                        523.333333                       2.000000
# 3                       -523.333333                      -2.000000
# 4                         72.666667                       1.000000
#
#    count_collected_small_pads_diff  amount_stolen_diff  \
# 0                             -6.0         -232.333333
# 1                              6.0          232.333333
# 2                             16.0          132.333333
# 3                            -16.0         -132.333333
# 4                              3.0          -53.000000
#
#    amount_stolen_big_pads_diff  amount_stolen_small_pads_diff  \
# 0                   -42.666667                    -189.666667
# 1                    42.666667                     189.666667
# 2                     8.333333                     124.000000
# 3                    -8.333333                    -124.000000
# 4                   -47.000000                      -6.000000
#
#    count_stolen_big_pads_diff  count_stolen_small_pads_diff  \
# 0                   -2.333333                     -8.666667
# 1                    2.333333                      8.666667
# 2                   -1.000000                      3.666667
# 3                    1.000000                     -3.666667
# 4                    0.333333                     -1.333333
#
#    0_boost_time_diff  avg_speed_diff  total_distance_diff  \
# 0           1.760000      122.333333         43895.666667
# 1          -1.760000     -122.333333        -43895.666667
# 2          18.090000      157.666667         54258.000000
# 3         -18.090000     -157.666667        -54258.000000
# 4         -20.193333      -10.000000         -7954.666667
#
#    time_slow_speed_diff  time_boost_speed_diff  time_supersonic_speed_diff  \
# 0            -38.663333              17.256667                   21.443333
# 1             38.663333             -17.256667                  -21.443333
# 2            -42.186667              17.320000                   24.766667
# 3             42.186667             -17.320000                  -24.766667
# 4              3.176667             -12.953333                    6.370000
#
#    time_on_ground_diff  time_low_in_air_diff  time_high_in_air_diff  \
# 0           -18.923333             12.983333               5.976667
# 1            18.923333            -12.983333              -5.976667
# 2           -14.363333             16.350000              -2.093333
# 3            14.363333            -16.350000               2.093333
# 4            -6.830000             -0.410000               3.826667
#
#    avg_distance_to_ball_diff  avg_distance_to_ball_has_possession_diff  \
# 0                      269.0                                125.666667
# 1                     -269.0                               -125.666667
# 2                     -479.0                               -833.333333
# 3                      479.0                                833.333333
# 4                       40.0                                -43.333333
#
#    avg_distance_to_ball_no_possession_diff  time_behind_ball_diff  \
# 0                               469.333333              23.036667
# 1                              -469.333333             -23.036667
# 2                               -97.333333             -25.236667
# 3                                97.333333              25.236667
# 4                               133.666667             -32.450000
#
#    time_in_front_of_ball_diff  time_defensive_half_diff  \
# 0                  -23.000000                -43.770000
# 1                   23.000000                 43.770000
# 2                   25.130000                -18.726667
# 3                  -25.130000                 18.726667
# 4                   29.043333                 21.250000
#
#    time_offensive_half_diff  time_defensive_third_diff  \
# 0                 43.810000                     -45.39
# 1                -43.810000                      45.39
# 2                 18.626667                     -15.15
# 3                -18.626667                      15.15
# 4                -24.660000                      22.73
#
#    time_neutral_third_diff  time_offensive_third_diff  demos_inflicted_diff  \
# 0                     0.35                  45.073333                   0.0
# 1                    -0.35                 -45.073333                   0.0
# 2                     1.69                  13.350000                   0.0
# 3                    -1.69                 -13.350000                   0.0
# 4                   -13.25                 -12.890000                  -1.0
#
#    demos_taken_diff  win
# 0               0.0    1
# 1               0.0    0
# 2               0.0    0
# 3               0.0    1
# 4               1.0    0

# %%
# Use what we learned from feature selection

df = df[['score', 'game_duration', 'time_behind_ball_diff',
                        'saves', 'time_in_front_of_ball', 'time_defensive_half',
                        'time_on_ground', 'total_distance', 'time_low_in_air',
                        'time_neutral_third_diff', 'time_high_in_air_diff',
                        'time_defensive_third', 'avg_distance_to_ball_has_possession_diff',
                        'time_slow_speed', 'avg_distance_to_ball_no_possession',
                        'total_distance_diff', 'amount_collected_diff', 'time_behind_ball',
                        'win']]

# %%
lose = df[df['win'] == 0]
win = df[df['win'] == 1]
sns.lineplot(x=lose.index, y=lose['time_behind_ball_diff'], legend='full', alpha=.5, color='red')
sns.lineplot(x=win.index, y=win['time_behind_ball_diff'], legend='full', alpha=0.5, color='blue')

# shows that there is a correlation between making sure you are behind the ball and winning

# %%
sns.lineplot(x=lose['score'], y=lose['time_defensive_half'], legend='full', alpha=.5, color='red')
sns.lineplot(x=win['score'], y=win['time_defensive_half'], legend='full', alpha=0.5, color='blue')

# %%
sns.lineplot(x=lose['game_duration'], y=lose['score'], legend='full', alpha=0.5, color='red', size=0.1)
sns.lineplot(x=win['game_duration'], y=win['score'], legend='full', alpha=0.2, color='blue', size=0.1)
# Out:
# /home/max/anaconda3/envs/Machine_Learning/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
temp_win = win[win['time_on_ground'] != 0]
temp_lose = lose[lose['time_on_ground'] != 0]

sns.scatterplot(x=temp_lose['score'], y=temp_lose['time_on_ground'], legend='full', alpha=0.5, color='red', size=0.1)
sns.scatterplot(x=temp_win['score'], y=temp_win['time_on_ground'], legend='full', alpha=0.2, color='blue', size=0.1)

print(temp_win['time_on_ground'].quantile(.25), '  --  ', temp_win['time_on_ground'].quantile(.75))
print(temp_lose['time_on_ground'].quantile(.25), '  --  ', temp_lose['time_on_ground'].quantile(.75))
# Out:
# 188.4466666666667   --   220.48333333333335
# 187.48333333333335   --   220.085

# %%
sns.lineplot(x=lose['score'], y=lose['time_slow_speed'], legend='full', alpha=0.5, color='red', size=0.1)
sns.lineplot(x=win['score'], y=win['time_slow_speed'], legend='full', alpha=0.2, color='blue', size=0.1)

# %% [raw]
# Main Take-aways:
#
# Play faster
# Get off the ground quick for high balls
# Play in control (don't overcommit and cherry pick)
